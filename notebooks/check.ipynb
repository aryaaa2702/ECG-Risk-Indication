# %%
import numpy
import pandas
import matplotlib
import scipy
import sklearn
import wfdb

print("All required packages are installed ✅")

# %%
# %pip install wfdb

# %%
print("hi")
# Out:
# hi

# %%
import sys
print(sys.executable)
# Out:
# C:\Users\ARYA\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\python.exe

# %%
import wfdb
wfdb.__version__
# Out:
# '4.3.0'

# %%
import wfdb
print("wfdb working")
# Out:
# wfdb working
